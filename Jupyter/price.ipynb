# %%
# xc90@xc90deMac-mini Downloads % cd ~/Documents/TradingDev/virtualenv
# xc90@xc90deMac-mini virtualenv % python -m venv tradeenv
# xc90@xc90deMac-mini virtualenv % source tradeenv/bin/activate
# (tradeenv) xc90@xc90deMac-mini virtualenv % pip install futu-api

from futu import *
quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)
ret, data, page_req_key = quote_ctx.request_history_kline(
    code='US.INTC',
    start='2023-01-01',
    end='2023-01-31',
    ktype=KLType.K_DAY,
    autype=AuType.QFQ,
    max_count=1000
)
if ret == RET_OK:
    print(data)
else:
    print('error:', data)
quote_ctx.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       1 # xc90@xc90deMac-mini Downloads % cd ~/Documents/TradingDev/virtualenv
#       2 # xc90@xc90deMac-mini virtualenv % python -m venv tradeenv
#       3 # xc90@xc90deMac-mini virtualenv % source tradeenv/bin/activate
#       4 # (tradeenv) xc90@xc90deMac-mini virtualenv % pip install futu-api
# ----> 6 from futu import *
#       7 quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)
#       8 ret, data, page_req_key = quote_ctx.request_history_kline(
#       9     code='US.INTC',
#      10     start='2023-01-01',
#    (...)     14     max_count=1000
#      15 )
#
# ModuleNotFoundError: No module named 'futu'
