# %%
import pandas as pd


csv_file_path = 'ES-12月14.csv' 

df = pd.read_csv(
    csv_file_path, 
    encoding='utf-8',       # 常用编码，可根据您的文件情况修改为 'gbk' 或 'latin-1'
    sep=',',                # 分隔符，默认是逗号，如果您的文件是 Tab 分隔，可改为 '\t'
    skiprows=0              # 跳过文件开头的行数 (0 表示不跳过)
)
df.info()
print("========================================================================================================")
print(df.head())
print("========================================================================================================")
print(df.tail())
print("========================================================================================================")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629086 entries, 0 to 1629085
# Data columns (total 8 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   date      1629086 non-null  object
#  1   open      1629086 non-null  float64
#  2   high      1629085 non-null  float64
#  3   low       1629085 non-null  float64
#  4   close     1629085 non-null  float64
#  5   volume    1629085 non-null  float64
#  6   average   1629085 non-null  float64
#  7   barCount  1629085 non-null  float64
# dtypes: float64(7), object(1)
# memory usage: 99.4+ MB
# ========================================================================================================
#                   date     open     high      low    close  volume   average  \
# 0  2018-10-01 00:51:00  2935.25  2935.50  2935.25  2935.50    30.0  2935.325
# 1  2018-10-01 00:52:00  2935.25  2935.50  2935.25  2935.50    94.0  2935.375
# 2  2018-10-01 00:53:00  2935.50  2935.50  2935.25  2935.50   161.0  2935.500
# 3  2018-10-01 00:54:00  2935.75  2935.75  2935.50  2935.75    69.0  2935.725
# 4  2018-10-01 00:55:00  2935.75  2935.75  2935.50  2935.75   161.0  2935.750
#
#    barCount
# 0      16.0
# 1      18.0
# 2      46.0
# 3      16.0
# 4      66.0
# ========================================================================================================
#                         date    open     high      low    close  volume  \
# 1629081  2023-05-17 06:27:00  4135.0  4135.50  4134.75  4135.00   196.0
# 1629082  2023-05-17 06:28:00  4135.0  4135.25  4135.00  4135.00   116.0
# 1629083  2023-05-17 06:29:00  4135.0  4135.50  4135.00  4135.50   108.0
# 1629084  2023-05-17 06:30:00  4135.5  4136.50  4133.00  4133.75  2383.0
# 1629085  2023-05-17 06:31:00  4134.0      NaN      NaN      NaN     NaN
#
#           average  barCount
# 1629081  4135.025      48.0
# 1629082  4135.000      45.0
# 1629083  4135.375      63.0
# 1629084  4134.225     594.0
# 1629085       NaN       NaN
# ========================================================================================================
